# %% [markdown]
# ### Convolutional Neural Network Testing
# All credit for the NN goes to Ian Flores.
# This notebook is meant for testing the NN with only two classes:
# x species or not x species

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
import os
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
# Out:
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### Deep Convolution Neural Network
# batch_size = 79
# patch_size = 2
# depth = 5
# num_hidden = 100

# %% [markdown]
# ### Structure of the Network
# Input Layer: image
# Layer 1: First Convolution Layer
# Pooling: RELU
# Layer 2: Second Convolution Layer
# Pooling: RELU
# Layer 5: Reshape
# Layer 6: RELU

# %%
def convNN(pickle_file):

    name = pickle_file.split('/')[-1].split('.')[0].split('_')[-1]
    
    print(f"Using binary {name} dataset\n")
    
    with open(pickle_file, 'rb') as f:
        save = pickle.load(f)
        train_dataset = save['train_dataset']
        train_labels = save['train_labels']
        valid_dataset = save['valid_dataset']
        valid_labels = save['valid_labels']
        test_dataset = save['test_dataset']
        test_labels = save['test_labels']
        del save  # hint to help gc free up memory
        print('Training set', train_dataset.shape, train_labels.shape)
        print('Validation set', valid_dataset.shape, valid_labels.shape)
        print('Test set', test_dataset.shape, test_labels.shape)

    #print(list(test_labels))
    
    image_size = 100
    num_labels = 2
    num_channels = 1 # grayscale

    def reformat(dataset, labels):
        dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
        labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
        return dataset, labels
    train_dataset, train_labels = reformat(train_dataset, train_labels)
    valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
    test_dataset, test_labels = reformat(test_dataset, test_labels)
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
    print(test_labels.shape)
    
    def accuracy(predictions, labels):
        return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
              / predictions.shape[0])
    
    cms = []

    batch_size = 100
    patch_size = 2
    depth = 5
    num_hidden = 100

    graph = tf.Graph()

    with graph.as_default():

        # Input data.
        tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
        tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
        tf_valid_dataset = tf.constant(valid_dataset)
        tf_test_dataset = tf.constant(test_dataset)

        # Variables.
        layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
        layer1_biases = tf.Variable(tf.zeros([depth]))
        layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
        layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
        layer3_weights = tf.Variable(tf.truncated_normal(
          [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
        layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
        layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_labels], stddev=0.1))
        layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

        tf_test_labels = tf.constant(test_labels)

        # Model.
        def model(data):
            conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(conv + layer1_biases)
            conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(conv + layer2_biases)
            shape = hidden.get_shape().as_list()
            reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
            hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
            return tf.matmul(hidden, layer4_weights) + layer4_biases

        # Training computation.
        logits = model(tf_train_dataset)
        loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

        # Optimizer.
        optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

        # Predictions for the training, validation, and test data.
        train_prediction = tf.nn.softmax(logits)
        valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
        test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
    num_steps = 1001

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print(f"Initialized NN with {name} dataset")
        for step in range(num_steps):
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run(
              [optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))

        preds = test_prediction.eval()
        preds = tf.reshape(preds, [-1])
        tf_test_labels = tf.reshape(tf_test_labels, [-1])
        cm = tf.confusion_matrix(tf_test_labels, preds, 2)
        cm = cm.eval()
        preds = preds.eval()
        lbls = tf_test_labels.eval()
        
        cms.append(cm)
        
        print('Test accuracy of %s: %.1f%%' % (name, accuracy(test_prediction.eval(), test_labels)))
    print("\n\n\n")
    return cms

# %%
datasets = '../dataset/arbimon_bin_datasets'

cms = []

#for dataset in os.listdir(datasets):
cms = convNN(datasets+'/'+datasets[i])
# Out:
# Using binary Eleutherodactylus cooki dataset
#
# Training set (656, 100, 100) (656,)
# Validation set (262, 100, 100) (262,)
# Test set (393, 100, 100) (393,)
# Training set (656, 100, 100, 1) (656, 2)
# Validation set (262, 100, 100, 1) (262, 2)
# Test set (393, 100, 100, 1) (393, 2)
# (393, 2)
# Initialized NN with Eleutherodactylus cooki dataset
# Minibatch loss at step 0: 7.919786
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.001323
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.003381
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.007145
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.012466
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.019582
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.028401
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.039419
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.054007
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.069201
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.082497
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.093135
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.102610
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.113399
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.127832
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.144282
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.165918
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.192681
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.224593
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.261420
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.302276
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Eleutherodactylus cooki: 49.9%
#
#
#
#
# Using binary Unknown Insect dataset
#
# Training set (410, 100, 100) (410,)
# Validation set (164, 100, 100) (164,)
# Test set (246, 100, 100) (246,)
# Training set (410, 100, 100, 1) (410, 2)
# Validation set (164, 100, 100, 1) (164, 2)
# Test set (246, 100, 100, 1) (246, 2)
# (246, 2)
# Initialized NN with Unknown Insect dataset
# Minibatch loss at step 0: 2.290900
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 8.688122
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 4.521920
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.508998
# Minibatch accuracy: 85.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 2.371374
# Minibatch accuracy: 45.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.249559
# Minibatch accuracy: 5.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 1.244665
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.267652
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 2.503489
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 2.312537
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 2.202774
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.568000
# Minibatch accuracy: 75.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.974433
# Minibatch accuracy: 35.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 1.894435
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.933383
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.428275
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 1.128010
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 1.408795
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.351967
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.648772
# Minibatch accuracy: 65.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.750045
# Minibatch accuracy: 25.0%
# Validation accuracy: 50.0%
# Test accuracy of Unknown Insect: 50.0%
#
#
#
#
# Using binary Myrmeciza hemimelaena dataset
#
# Training set (1886, 100, 100) (1886,)
# Validation set (754, 100, 100) (754,)
# Test set (1131, 100, 100) (1131,)
# Training set (1886, 100, 100, 1) (1886, 2)
# Validation set (754, 100, 100, 1) (754, 2)
# Test set (1131, 100, 100, 1) (1131, 2)
# (1131, 2)
# Initialized NN with Myrmeciza hemimelaena dataset
# Minibatch loss at step 0: 0.075441
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.231583
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.784823
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.635007
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.717165
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.583487
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.686851
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.772915
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.635763
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.713999
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.581297
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.693250
# Minibatch accuracy: 44.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.785021
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.624265
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.697651
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.489344
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.595783
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.769575
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.541135
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.553749
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.109426
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Myrmeciza hemimelaena: 50.0%
#
#
#
#
# Using binary Megascops nudipes dataset
#
# Training set (615, 100, 100) (615,)
# Validation set (246, 100, 100) (246,)
# Test set (369, 100, 100) (369,)
# Training set (615, 100, 100, 1) (615, 2)
# Validation set (246, 100, 100, 1) (246, 2)
# Test set (369, 100, 100, 1) (369, 2)
# (369, 2)
# Initialized NN with Megascops nudipes dataset
# Minibatch loss at step 0: 0.002793
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 1.334749
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.335331
# Minibatch accuracy: 92.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 3.659513
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.001594
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.393065
# Minibatch accuracy: 27.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.042526
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.036282
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 1.273952
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.066693
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 3.352671
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.093866
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 1.449489
# Minibatch accuracy: 47.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.160554
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.108930
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 2.001554
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.301409
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 2.244354
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.495066
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.727837
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 2.138069
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Test accuracy of Megascops nudipes: 50.1%
#
#
#
#
# Using binary Thamnophilus schistaceus dataset
#
# Training set (451, 100, 100) (451,)
# Validation set (180, 100, 100) (180,)
# Test set (270, 100, 100) (270,)
# Training set (451, 100, 100, 1) (451, 2)
# Validation set (180, 100, 100, 1) (180, 2)
# Test set (270, 100, 100, 1) (270, 2)
# (270, 2)
# Initialized NN with Thamnophilus schistaceus dataset
# Minibatch loss at step 0: 1.173616
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 4.885527
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 2.030087
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 1.876007
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.021706
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.267952
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 1.087554
# Minibatch accuracy: 60.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 1.625912
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.126479
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 2.294606
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.671902
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 1.549805
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.332757
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 1.737202
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.581236
# Minibatch accuracy: 74.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 1.444960
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.537372
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 1.317682
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.601476
# Minibatch accuracy: 81.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 1.327457
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.693099
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Thamnophilus schistaceus: 50.0%
#
#
#
#
# Using binary Eleutherodactylus brittoni dataset
#
# Training set (574, 100, 100) (574,)
# Validation set (229, 100, 100) (229,)
# Test set (344, 100, 100) (344,)
# Training set (574, 100, 100, 1) (574, 2)
# Validation set (229, 100, 100, 1) (229, 2)
# Test set (344, 100, 100, 1) (344, 2)
# (344, 2)
# Initialized NN with Eleutherodactylus brittoni dataset
# Minibatch loss at step 0: 1.968459
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 50: 3.778184
# Minibatch accuracy: 27.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 100: 5.988447
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 150: 3.295463
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 200: 3.326599
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 250: 0.286646
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 300: 0.083789
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 350: 0.047450
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 400: 0.099517
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 450: 0.078323
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 500: 1.125645
# Minibatch accuracy: 57.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 550: 2.443855
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 600: 1.986990
# Minibatch accuracy: 11.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 650: 2.377751
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 700: 1.429887
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 750: 0.343232
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 800: 0.583946
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 850: 0.457597
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 900: 0.415785
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 950: 0.404169
# Minibatch accuracy: 87.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 1000: 0.316410
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Test accuracy of Eleutherodactylus brittoni: 50.0%
#
#
#
#
# Using binary Eleutherodactylus cochranae dataset
#
# Training set (1025, 100, 100) (1025,)
# Validation set (410, 100, 100) (410,)
# Test set (615, 100, 100) (615,)
# Training set (1025, 100, 100, 1) (1025, 2)
# Validation set (410, 100, 100, 1) (410, 2)
# Test set (615, 100, 100, 1) (615, 2)
# (615, 2)
# Initialized NN with Eleutherodactylus cochranae dataset
# Minibatch loss at step 0: 0.001879
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.002097
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.000423
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.023574
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.317269
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 6.532867
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.017454
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.021958
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.035133
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.055066
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 3.987564
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.499308
# Minibatch accuracy: 87.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.037857
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.041896
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.039627
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 3.558485
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 1.304548
# Minibatch accuracy: 62.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.039678
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.075710
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.067330
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.201837
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Eleutherodactylus cochranae: 49.9%
#
#
#
#
# Using binary Eleutherodactylus coqui dataset
#
# Training set (533, 100, 100) (533,)
# Validation set (213, 100, 100) (213,)
# Test set (319, 100, 100) (319,)
# Training set (533, 100, 100, 1) (533, 2)
# Validation set (213, 100, 100, 1) (213, 2)
# Test set (319, 100, 100, 1) (319, 2)
# (319, 2)
# Initialized NN with Eleutherodactylus coqui dataset
# Minibatch loss at step 0: 0.801138
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 50: 0.725528
# Minibatch accuracy: 29.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 100: 0.676840
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 150: 0.747773
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 200: 0.700196
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 250: 0.719024
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 300: 0.708531
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 350: 0.657983
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 400: 0.753000
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 450: 0.692087
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 500: 0.680854
# Minibatch accuracy: 61.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 550: 0.676179
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 600: 0.721374
# Minibatch accuracy: 20.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 650: 0.714605
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 700: 0.703813
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 750: 0.742221
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 800: 0.675589
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 850: 0.750858
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 900: 0.708243
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 950: 0.657120
# Minibatch accuracy: 93.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 1000: 0.731713
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Test accuracy of Eleutherodactylus coqui: 50.2%
#
#
#
#
# Using binary Eleutherodactylus juanariveroi dataset
#
# Training set (205, 100, 100) (205,)
# Validation set (82, 100, 100) (82,)
# Test set (123, 100, 100) (123,)
# Training set (205, 100, 100, 1) (205, 2)
# Validation set (82, 100, 100, 1) (82, 2)
# Test set (123, 100, 100, 1) (123, 2)
# (123, 2)
# Initialized NN with Eleutherodactylus juanariveroi dataset
# Minibatch loss at step 0: 0.000169
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.661814
# Minibatch accuracy: 63.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.657404
# Minibatch accuracy: 77.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.793637
# Minibatch accuracy: 12.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.692997
# Minibatch accuracy: 52.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.636348
# Minibatch accuracy: 92.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.705377
# Minibatch accuracy: 27.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.692180
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.826535
# Minibatch accuracy: 2.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.692650
# Minibatch accuracy: 58.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.671542
# Minibatch accuracy: 82.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.732972
# Minibatch accuracy: 17.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.694180
# Minibatch accuracy: 43.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.615653
# Minibatch accuracy: 97.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.697817
# Minibatch accuracy: 32.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.688363
# Minibatch accuracy: 72.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.786864
# Minibatch accuracy: 7.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.692748
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.657517
# Minibatch accuracy: 87.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.716266
# Minibatch accuracy: 22.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.693996
# Minibatch accuracy: 38.0%
# Validation accuracy: 50.0%
# Test accuracy of Eleutherodactylus juanariveroi: 50.4%
#
#
#
#
# Using binary Saltator grossus dataset
#
# Training set (410, 100, 100) (410,)
# Validation set (164, 100, 100) (164,)
# Test set (246, 100, 100) (246,)
# Training set (410, 100, 100, 1) (410, 2)
# Validation set (164, 100, 100, 1) (164, 2)
# Test set (246, 100, 100, 1) (246, 2)
# (246, 2)
# Initialized NN with Saltator grossus dataset
# Minibatch loss at step 0: 0.008095
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 8.526628
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 4.414932
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.507249
# Minibatch accuracy: 85.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 2.329946
# Minibatch accuracy: 45.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.224266
# Minibatch accuracy: 5.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 1.242397
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.270994
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 2.451592
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 2.284547
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 2.184013
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.566991
# Minibatch accuracy: 75.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.964744
# Minibatch accuracy: 35.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 1.882717
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.931644
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.430682
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 1.119961
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 1.401299
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.354064
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.648978
# Minibatch accuracy: 65.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.747745
# Minibatch accuracy: 25.0%
# Validation accuracy: 50.0%
# Test accuracy of Saltator grossus: 50.0%
#
#
#
#
# Using binary Myrmoborus leucophrys dataset
#
# Training set (902, 100, 100) (902,)
# Validation set (360, 100, 100) (360,)
# Test set (541, 100, 100) (541,)
# Training set (902, 100, 100, 1) (902, 2)
# Validation set (360, 100, 100, 1) (360, 2)
# Test set (541, 100, 100, 1) (541, 2)
# (541, 2)
# Initialized NN with Myrmoborus leucophrys dataset
# Minibatch loss at step 0: 0.029097
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.763630
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.711678
# Minibatch accuracy: 25.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.665177
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.644623
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.711885
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.635463
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.799316
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.774130
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.784637
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.755052
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.690327
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.668248
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.738774
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.658424
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.727904
# Minibatch accuracy: 37.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.804289
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.630954
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.784227
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.709571
# Minibatch accuracy: 13.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.692925
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Myrmoborus leucophrys: 49.9%
#
#
#
#
# Using binary Percnostola lophotes dataset
#
# Training set (697, 100, 100) (697,)
# Validation set (278, 100, 100) (278,)
# Test set (418, 100, 100) (418,)
# Training set (697, 100, 100, 1) (697, 2)
# Validation set (278, 100, 100, 1) (278, 2)
# Test set (418, 100, 100, 1) (418, 2)
# (418, 2)
# Initialized NN with Percnostola lophotes dataset
# Minibatch loss at step 0: 0.009873
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.624878
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.746729
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.758388
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.694839
# Minibatch accuracy: 51.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.734758
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.668963
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.696601
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.823025
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.628825
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.742700
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.762005
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.692351
# Minibatch accuracy: 52.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.745188
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.668467
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.694094
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.826498
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.631754
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.739014
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.765538
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.691540
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Test accuracy of Percnostola lophotes: 50.0%
#
#
#
#
# Using binary Basileuterus chrysogaster dataset
#
# Training set (205, 100, 100) (205,)
# Validation set (82, 100, 100) (82,)
# Test set (123, 100, 100) (123,)
# Training set (205, 100, 100, 1) (205, 2)
# Validation set (82, 100, 100, 1) (82, 2)
# Test set (123, 100, 100, 1) (123, 2)
# (123, 2)
# Initialized NN with Basileuterus chrysogaster dataset
# Minibatch loss at step 0: 0.000388
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.664718
# Minibatch accuracy: 63.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.582182
# Minibatch accuracy: 77.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.801346
# Minibatch accuracy: 12.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.692911
# Minibatch accuracy: 52.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.635809
# Minibatch accuracy: 92.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.705474
# Minibatch accuracy: 27.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.692161
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.826552
# Minibatch accuracy: 2.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.692651
# Minibatch accuracy: 58.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.671541
# Minibatch accuracy: 82.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.732972
# Minibatch accuracy: 17.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.694180
# Minibatch accuracy: 43.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.615653
# Minibatch accuracy: 97.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.697817
# Minibatch accuracy: 32.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.688363
# Minibatch accuracy: 72.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.786864
# Minibatch accuracy: 7.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.692748
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.657517
# Minibatch accuracy: 87.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.716266
# Minibatch accuracy: 22.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.693996
# Minibatch accuracy: 38.0%
# Validation accuracy: 50.0%
# Test accuracy of Basileuterus chrysogaster: 50.4%
#
#
#
#
# Using binary Basileuterus bivittatus dataset
#
# Training set (615, 100, 100) (615,)
# Validation set (246, 100, 100) (246,)
# Test set (369, 100, 100) (369,)
# Training set (615, 100, 100, 1) (615, 2)
# Validation set (246, 100, 100, 1) (246, 2)
# Test set (369, 100, 100, 1) (369, 2)
# (369, 2)
# Initialized NN with Basileuterus bivittatus dataset
# Minibatch loss at step 0: 11.104057
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 1.135907
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.316595
# Minibatch accuracy: 92.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 3.562210
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.003206
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.117848
# Minibatch accuracy: 27.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.055024
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.046400
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 1.278558
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.087647
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 3.165257
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.127888
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 1.369510
# Minibatch accuracy: 47.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.192259
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.124896
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 1.954418
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.352753
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 2.115051
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.532693
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.707870
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 2.036971
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Test accuracy of Basileuterus bivittatus: 50.1%
#
#
#
#
# Using binary Hypocnemis subflava dataset
#
# Training set (984, 100, 100) (984,)
# Validation set (393, 100, 100) (393,)
# Test set (590, 100, 100) (590,)
# Training set (984, 100, 100, 1) (984, 2)
# Validation set (393, 100, 100, 1) (393, 2)
# Test set (590, 100, 100, 1) (590, 2)
# (590, 2)
# Initialized NN with Hypocnemis subflava dataset
# Minibatch loss at step 0: 4.898340
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 50: 0.051055
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 100: 0.002397
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 150: 0.015173
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 200: 0.364210
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 250: 0.019351
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 300: 0.004523
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 350: 1.685015
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 400: 0.028316
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 450: 0.017974
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 500: 3.639045
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 550: 0.048584
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 600: 0.044023
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 650: 2.660482
# Minibatch accuracy: 24.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 700: 0.117982
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 750: 0.036920
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 800: 1.574889
# Minibatch accuracy: 52.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 850: 0.189540
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 900: 0.064770
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.1%
# Minibatch loss at step 950: 0.651401
# Minibatch accuracy: 80.0%
# Validation accuracy: 49.9%
# Minibatch loss at step 1000: 0.251885
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.9%
# Test accuracy of Hypocnemis subflava: 50.0%
#
#
#
#
# Using binary Formicarius analis dataset
#
# Training set (451, 100, 100) (451,)
# Validation set (180, 100, 100) (180,)
# Test set (270, 100, 100) (270,)
# Training set (451, 100, 100, 1) (451, 2)
# Validation set (180, 100, 100, 1) (180, 2)
# Test set (270, 100, 100, 1) (270, 2)
# (270, 2)
# Initialized NN with Formicarius analis dataset
# Minibatch loss at step 0: 0.015605
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 5.181137
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 2.209333
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 1.983310
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.015324
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.489291
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 1.185983
# Minibatch accuracy: 60.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 1.708466
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.101643
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 2.400819
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.692746
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 1.597920
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.299930
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 1.814119
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.577738
# Minibatch accuracy: 74.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 1.492286
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.514501
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 1.371109
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.591770
# Minibatch accuracy: 81.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 1.366818
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.681532
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Formicarius analis: 50.0%
#
#
#
#
# Using binary Chlorothraupis carmioli dataset
#
# Training set (451, 100, 100) (451,)
# Validation set (180, 100, 100) (180,)
# Test set (270, 100, 100) (270,)
# Training set (451, 100, 100, 1) (451, 2)
# Validation set (180, 100, 100, 1) (180, 2)
# Test set (270, 100, 100, 1) (270, 2)
# (270, 2)
# Initialized NN with Chlorothraupis carmioli dataset
# Minibatch loss at step 0: 0.001823
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 5.098457
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 2.159346
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 1.955449
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.016851
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 3.427529
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 1.157948
# Minibatch accuracy: 60.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 1.683658
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.108064
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 2.371116
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.686366
# Minibatch accuracy: 67.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 1.584557
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.308849
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 1.792894
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.578647
# Minibatch accuracy: 74.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 1.479185
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.520780
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 1.356247
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.594519
# Minibatch accuracy: 81.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 1.355841
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.684650
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Chlorothraupis carmioli: 50.0%
#
#
#
#
# Using binary Megascops guatemalae dataset
#
# Training set (246, 100, 100) (246,)
# Validation set (98, 100, 100) (98,)
# Test set (147, 100, 100) (147,)
# Training set (246, 100, 100, 1) (246, 2)
# Validation set (98, 100, 100, 1) (98, 2)
# Test set (147, 100, 100, 1) (147, 2)
# (147, 2)
# Initialized NN with Megascops guatemalae dataset
# Minibatch loss at step 0: 0.215073
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.699412
# Minibatch accuracy: 13.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.692950
# Minibatch accuracy: 51.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.717550
# Minibatch accuracy: 15.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.700809
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.678080
# Minibatch accuracy: 89.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.691999
# Minibatch accuracy: 53.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.698080
# Minibatch accuracy: 17.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.713627
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.677411
# Minibatch accuracy: 91.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.693000
# Minibatch accuracy: 55.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.706024
# Minibatch accuracy: 19.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.716359
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.691397
# Minibatch accuracy: 93.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.691022
# Minibatch accuracy: 57.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.707823
# Minibatch accuracy: 21.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.703340
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.676977
# Minibatch accuracy: 95.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.689287
# Minibatch accuracy: 59.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.701428
# Minibatch accuracy: 23.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.721132
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Test accuracy of Megascops guatemalae: 50.3%
#
#
#
#
# Using binary Microcerculus marginatus dataset
#
# Training set (492, 100, 100) (492,)
# Validation set (196, 100, 100) (196,)
# Test set (295, 100, 100) (295,)
# Training set (492, 100, 100, 1) (492, 2)
# Validation set (196, 100, 100, 1) (196, 2)
# Test set (295, 100, 100, 1) (295, 2)
# (295, 2)
# Initialized NN with Microcerculus marginatus dataset
# Minibatch loss at step 0: 0.387087
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.659278
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.693259
# Minibatch accuracy: 46.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 0.721990
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 0.718042
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.686803
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.699746
# Minibatch accuracy: 38.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 0.698563
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 0.699216
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.704452
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.711548
# Minibatch accuracy: 30.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 0.681899
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 0.686449
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.716543
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.725929
# Minibatch accuracy: 22.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 0.670791
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 0.678887
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.723465
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.740513
# Minibatch accuracy: 14.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 0.664547
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 0.675928
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Test accuracy of Microcerculus marginatus: 50.2%
#
#
#
#
# Using binary Epinephelus guttatus dataset
#
# Training set (697, 100, 100) (697,)
# Validation set (278, 100, 100) (278,)
# Test set (418, 100, 100) (418,)
# Training set (697, 100, 100, 1) (697, 2)
# Validation set (278, 100, 100, 1) (278, 2)
# Test set (418, 100, 100, 1) (418, 2)
# (418, 2)
# Initialized NN with Epinephelus guttatus dataset
# Minibatch loss at step 0: 0.005866
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 50: 0.001993
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 100: 0.016669
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 150: 5.859498
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 200: 2.049951
# Minibatch accuracy: 49.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 250: 0.050554
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 300: 0.031377
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 350: 1.738372
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 400: 3.509016
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 450: 0.045765
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 500: 0.098402
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 550: 3.317727
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 600: 1.535940
# Minibatch accuracy: 48.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 650: 0.102586
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 700: 0.233256
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 750: 1.658163
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 800: 2.426502
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 850: 0.138861
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 900: 0.391812
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 950: 2.350364
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.0%
# Minibatch loss at step 1000: 1.216748
# Minibatch accuracy: 47.0%
# Validation accuracy: 50.0%
# Test accuracy of Epinephelus guttatus: 50.0%
#
#
#
#
# Using binary Liosceles thoracicus dataset
#
# Training set (574, 100, 100) (574,)
# Validation set (229, 100, 100) (229,)
# Test set (344, 100, 100) (344,)
# Training set (574, 100, 100, 1) (574, 2)
# Validation set (229, 100, 100, 1) (229, 2)
# Test set (344, 100, 100, 1) (344, 2)
# (344, 2)
# Initialized NN with Liosceles thoracicus dataset
# Minibatch loss at step 0: 1.359066
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 50: 3.671909
# Minibatch accuracy: 27.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 100: 5.804094
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 150: 3.192627
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 200: 3.302112
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 250: 0.302114
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 300: 0.088111
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 350: 0.051720
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 400: 0.108692
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 450: 0.082058
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 500: 1.112458
# Minibatch accuracy: 57.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 550: 2.406741
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 600: 1.959590
# Minibatch accuracy: 11.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 650: 2.341792
# Minibatch accuracy: 0.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 700: 1.426050
# Minibatch accuracy: 0.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 750: 0.353810
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 800: 0.592486
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 850: 0.466767
# Minibatch accuracy: 100.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 900: 0.426325
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Minibatch loss at step 950: 0.406113
# Minibatch accuracy: 87.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 1000: 0.323203
# Minibatch accuracy: 100.0%
# Validation accuracy: 49.8%
# Test accuracy of Liosceles thoracicus: 50.0%

# %%
import matplotlib.pyplot as plt
import itertools
    
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

for cm in cms:
    # Compute confusion matrix
    cnf_matrix = cm
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure(num=1, figsize=(12, 12), dpi=80)
    plot_confusion_matrix(cnf_matrix, classes=list(range(2)),title='Confusion matrix, without normalization')
    #plt.figure(num=1, figsize=(8, 6), dpi=80)

    # Plot normalized confusion matrix
    plt.figure(num=2, figsize=(12, 12), dpi=80)
    plot_confusion_matrix(cnf_matrix, classes=list(range(2)), normalize=True, title='Normalized confusion matrix')
    #plt.figure(num=2, figsize=(8, 6), dpi=80)

    plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix
