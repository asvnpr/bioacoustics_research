# %% [markdown]
# ### Testing Ian's Conv NN with balanced classes

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/font_manager.py:279: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def convNN(file):

    pickle_file = '../dataset/arbimonBalanced.pickle'
    
    with open(pickle_file, 'rb') as f:
        save = pickle.load(f)
        train_dataset = save['train_dataset']
        train_labels = save['train_labels']
        valid_dataset = save['valid_dataset']
        valid_labels = save['valid_labels']
        test_dataset = save['test_dataset']
        test_labels = save['test_labels']
        del save  # hint to help gc free up memory
        print('Training set', train_dataset.shape, train_labels.shape)
        print('Validation set', valid_dataset.shape, valid_labels.shape)
        print('Test set', test_dataset.shape, test_labels.shape)

    #print(list(test_labels))
    
    image_size = 100
    num_labels = 21
    num_channels = 1 # grayscale

    def reformat(dataset, labels):
        dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
        labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
        return dataset, labels
    train_dataset, train_labels = reformat(train_dataset, train_labels)
    valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
    test_dataset, test_labels = reformat(test_dataset, test_labels)
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
    print(test_labels.shape)
    
    def accuracy(predictions, labels):
        return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
              / predictions.shape[0])
    
    cms = []

    batch_size = 1000
    patch_size = 2
    depth = 5
    num_hidden = 100

    graph = tf.Graph()

    with graph.as_default():

        # Input data.
        tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
        tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
        tf_valid_dataset = tf.constant(valid_dataset)
        tf_test_dataset = tf.constant(test_dataset)

        # Variables.
        layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
        layer1_biases = tf.Variable(tf.zeros([depth]))
        layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
        layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
        layer3_weights = tf.Variable(tf.truncated_normal(
          [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
        layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
        layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_labels], stddev=0.1))
        layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

        tf_test_labels = tf.constant(test_labels)

        # Model.
        def model(data):
            conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(conv + layer1_biases)
            conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
            hidden = tf.nn.relu(conv + layer2_biases)
            shape = hidden.get_shape().as_list()
            reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
            hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
            return tf.matmul(hidden, layer4_weights) + layer4_biases

        # Training computation.
        logits = model(tf_train_dataset)
        loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

        # Optimizer.
        optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

        # Predictions for the training, validation, and test data.
        train_prediction = tf.nn.softmax(logits)
        valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
        test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
    num_steps = 1001

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print(f"Initialized")
        for step in range(num_steps):
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = session.run(
              [optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 50 == 0):
                print('Minibatch loss at step %d: %f' % (step, l))
                print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
                print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))

        preds = test_prediction.eval()
        preds = tf.reshape(preds, [-1])
        tf_test_labels = tf.reshape(tf_test_labels, [-1])
        cm = tf.contrib.metrics.confusion_matrix(tf_test_labels, preds, 2)
        cm = cm.eval()
        preds = preds.eval()
        lbls = tf_test_labels.eval()
        
        
        
        print('Test accuracy: %.1f%%' % (accuracy(test_prediction.eval(), test_labels)))
    
        with open(file, "a+") as f:
            f.write('Test accuracy: %.1f%%' % (accuracy(test_prediction.eval(), test_labels)))
            f.close()
    
        return cm

# %%
for i in range(15):
    cm = convNN('../dataset/NN_results.txt')
# Out:
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 6.238378
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.699795
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.958075
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.737917
# Minibatch accuracy: 10.2%
# Validation accuracy: 6.6%
# Minibatch loss at step 200: 2.787144
# Minibatch accuracy: 10.2%
# Validation accuracy: 5.2%
# Minibatch loss at step 250: 3.241860
# Minibatch accuracy: 0.3%
# Validation accuracy: 8.7%
# Minibatch loss at step 300: 2.213307
# Minibatch accuracy: 39.0%
# Validation accuracy: 13.7%
# Minibatch loss at step 350: 2.355733
# Minibatch accuracy: 22.6%
# Validation accuracy: 24.3%
# Minibatch loss at step 400: 1.109590
# Minibatch accuracy: 69.4%
# Validation accuracy: 40.1%
# Minibatch loss at step 450: 1.534967
# Minibatch accuracy: 62.9%
# Validation accuracy: 46.0%
# Minibatch loss at step 500: 0.968951
# Minibatch accuracy: 72.6%
# Validation accuracy: 57.3%
# Minibatch loss at step 550: 0.416813
# Minibatch accuracy: 87.9%
# Validation accuracy: 63.0%
# Minibatch loss at step 600: 0.567287
# Minibatch accuracy: 81.3%
# Validation accuracy: 66.9%
# Minibatch loss at step 650: 0.278628
# Minibatch accuracy: 92.8%
# Validation accuracy: 71.7%
# Minibatch loss at step 700: 0.247433
# Minibatch accuracy: 92.1%
# Validation accuracy: 77.9%
# Minibatch loss at step 750: 0.241659
# Minibatch accuracy: 92.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 800: 0.079560
# Minibatch accuracy: 98.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 850: 0.093928
# Minibatch accuracy: 98.3%
# Validation accuracy: 85.1%
# Minibatch loss at step 900: 0.056012
# Minibatch accuracy: 99.1%
# Validation accuracy: 86.3%
# Minibatch loss at step 950: 0.085910
# Minibatch accuracy: 97.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 1000: 0.065527
# Minibatch accuracy: 98.9%
# Validation accuracy: 88.3%
# Test accuracy: 84.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 8.142916
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.704113
# Minibatch accuracy: 10.6%
# Validation accuracy: 5.8%
# Minibatch loss at step 100: 2.916126
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.803976
# Minibatch accuracy: 13.3%
# Validation accuracy: 4.9%
# Minibatch loss at step 200: 2.683920
# Minibatch accuracy: 17.9%
# Validation accuracy: 8.6%
# Minibatch loss at step 250: 3.196591
# Minibatch accuracy: 10.9%
# Validation accuracy: 6.9%
# Minibatch loss at step 300: 1.537425
# Minibatch accuracy: 45.8%
# Validation accuracy: 29.5%
# Minibatch loss at step 350: 1.506024
# Minibatch accuracy: 47.5%
# Validation accuracy: 38.2%
# Minibatch loss at step 400: 0.810000
# Minibatch accuracy: 77.7%
# Validation accuracy: 46.1%
# Minibatch loss at step 450: 0.821580
# Minibatch accuracy: 75.0%
# Validation accuracy: 54.2%
# Minibatch loss at step 500: 0.925648
# Minibatch accuracy: 77.6%
# Validation accuracy: 57.7%
# Minibatch loss at step 550: 0.326474
# Minibatch accuracy: 90.2%
# Validation accuracy: 62.7%
# Minibatch loss at step 600: 0.421907
# Minibatch accuracy: 87.9%
# Validation accuracy: 70.0%
# Minibatch loss at step 650: 0.217636
# Minibatch accuracy: 95.3%
# Validation accuracy: 70.2%
# Minibatch loss at step 700: 0.238002
# Minibatch accuracy: 92.7%
# Validation accuracy: 74.4%
# Minibatch loss at step 750: 0.270841
# Minibatch accuracy: 92.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 800: 0.059914
# Minibatch accuracy: 98.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 850: 0.086517
# Minibatch accuracy: 98.3%
# Validation accuracy: 83.9%
# Minibatch loss at step 900: 0.047450
# Minibatch accuracy: 99.1%
# Validation accuracy: 85.1%
# Minibatch loss at step 950: 0.060745
# Minibatch accuracy: 98.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 1000: 0.067035
# Minibatch accuracy: 98.5%
# Validation accuracy: 87.7%
# Test accuracy: 83.8%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 8.249104
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.724599
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.965281
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.708894
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.846419
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.187255
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.741024
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.942020
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.760810
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.781089
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.158790
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.727697
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.945835
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.6%
# Minibatch loss at step 650: 2.711177
# Minibatch accuracy: 12.2%
# Validation accuracy: 6.7%
# Minibatch loss at step 700: 2.137401
# Minibatch accuracy: 38.5%
# Validation accuracy: 19.9%
# Minibatch loss at step 750: 2.466453
# Minibatch accuracy: 37.5%
# Validation accuracy: 19.0%
# Minibatch loss at step 800: 1.014876
# Minibatch accuracy: 74.4%
# Validation accuracy: 42.4%
# Minibatch loss at step 850: 1.259608
# Minibatch accuracy: 57.2%
# Validation accuracy: 50.8%
# Minibatch loss at step 900: 0.594523
# Minibatch accuracy: 85.0%
# Validation accuracy: 54.4%
# Minibatch loss at step 950: 0.556603
# Minibatch accuracy: 84.5%
# Validation accuracy: 64.0%
# Minibatch loss at step 1000: 0.635681
# Minibatch accuracy: 84.2%
# Validation accuracy: 64.9%
# Test accuracy: 62.3%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 5.447566
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.999933
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.997160
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.966396
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.888174
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.088093
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.830901
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.947263
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.897960
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.796177
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.119483
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.753078
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.949250
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 650: 2.857760
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 700: 2.757924
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 750: 3.129959
# Minibatch accuracy: 2.8%
# Validation accuracy: 4.8%
# Minibatch loss at step 800: 2.709966
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 850: 2.965650
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 900: 2.827690
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 950: 2.745302
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 1000: 3.126076
# Minibatch accuracy: 4.4%
# Validation accuracy: 4.8%
# Test accuracy: 4.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 6.837443
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.994985
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.993058
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.963590
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.884454
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.089617
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.829333
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.945985
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.896877
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.794579
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.120442
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.752522
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.948873
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 650: 2.857216
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 700: 2.757134
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 750: 3.130486
# Minibatch accuracy: 2.8%
# Validation accuracy: 4.8%
# Minibatch loss at step 800: 2.709712
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 850: 2.965542
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 900: 2.827349
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 950: 2.744915
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 1000: 3.126347
# Minibatch accuracy: 4.4%
# Validation accuracy: 4.8%
# Test accuracy: 4.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 6.996703
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.688213
# Minibatch accuracy: 9.5%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.960394
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.745746
# Minibatch accuracy: 11.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.772560
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.333712
# Minibatch accuracy: 8.6%
# Validation accuracy: 6.5%
# Minibatch loss at step 300: 2.483409
# Minibatch accuracy: 30.9%
# Validation accuracy: 11.8%
# Minibatch loss at step 350: 2.234162
# Minibatch accuracy: 30.3%
# Validation accuracy: 23.2%
# Minibatch loss at step 400: 1.233206
# Minibatch accuracy: 62.5%
# Validation accuracy: 35.8%
# Minibatch loss at step 450: 1.560540
# Minibatch accuracy: 57.2%
# Validation accuracy: 45.6%
# Minibatch loss at step 500: 1.270949
# Minibatch accuracy: 73.6%
# Validation accuracy: 54.2%
# Minibatch loss at step 550: 0.429000
# Minibatch accuracy: 89.0%
# Validation accuracy: 63.3%
# Minibatch loss at step 600: 0.469846
# Minibatch accuracy: 85.6%
# Validation accuracy: 70.5%
# Minibatch loss at step 650: 0.285256
# Minibatch accuracy: 94.3%
# Validation accuracy: 72.1%
# Minibatch loss at step 700: 0.248451
# Minibatch accuracy: 93.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 750: 0.347804
# Minibatch accuracy: 91.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 800: 0.084026
# Minibatch accuracy: 98.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 850: 0.084612
# Minibatch accuracy: 98.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 900: 0.044011
# Minibatch accuracy: 99.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 950: 0.051135
# Minibatch accuracy: 99.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 1000: 0.078314
# Minibatch accuracy: 98.5%
# Validation accuracy: 88.2%
# Test accuracy: 85.9%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 8.719013
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.768486
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.960605
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.740265
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.811882
# Minibatch accuracy: 9.1%
# Validation accuracy: 4.6%
# Minibatch loss at step 250: 3.200814
# Minibatch accuracy: 2.4%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.718214
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.940977
# Minibatch accuracy: 9.1%
# Validation accuracy: 5.0%
# Minibatch loss at step 400: 2.682932
# Minibatch accuracy: 12.7%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.089653
# Minibatch accuracy: 38.0%
# Validation accuracy: 19.7%
# Minibatch loss at step 500: 2.892710
# Minibatch accuracy: 29.0%
# Validation accuracy: 11.6%
# Minibatch loss at step 550: 1.056244
# Minibatch accuracy: 72.5%
# Validation accuracy: 43.0%
# Minibatch loss at step 600: 1.216407
# Minibatch accuracy: 61.1%
# Validation accuracy: 48.0%
# Minibatch loss at step 650: 0.681924
# Minibatch accuracy: 81.9%
# Validation accuracy: 52.6%
# Minibatch loss at step 700: 0.691151
# Minibatch accuracy: 77.9%
# Validation accuracy: 64.1%
# Minibatch loss at step 750: 0.786795
# Minibatch accuracy: 75.2%
# Validation accuracy: 57.0%
# Minibatch loss at step 800: 0.282709
# Minibatch accuracy: 91.8%
# Validation accuracy: 70.4%
# Minibatch loss at step 850: 0.390065
# Minibatch accuracy: 88.6%
# Validation accuracy: 74.4%
# Minibatch loss at step 900: 0.192784
# Minibatch accuracy: 94.9%
# Validation accuracy: 72.4%
# Minibatch loss at step 950: 0.191620
# Minibatch accuracy: 95.0%
# Validation accuracy: 77.6%
# Minibatch loss at step 1000: 0.234983
# Minibatch accuracy: 93.4%
# Validation accuracy: 81.5%
# Test accuracy: 78.6%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 5.986864
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.995469
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.994155
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.965265
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.884700
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.090888
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.829240
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.946070
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.897602
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.794675
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.121079
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.752367
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.948733
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 650: 2.857557
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 700: 2.757240
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 750: 3.130825
# Minibatch accuracy: 2.8%
# Validation accuracy: 4.8%
# Minibatch loss at step 800: 2.709607
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 850: 2.965394
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 900: 2.827523
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 950: 2.744978
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 1000: 3.126568
# Minibatch accuracy: 4.4%
# Validation accuracy: 4.8%
# Test accuracy: 4.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 6.954899
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.697330
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.959947
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.726974
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.813431
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.224270
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.715760
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.956927
# Minibatch accuracy: 10.8%
# Validation accuracy: 6.3%
# Minibatch loss at step 400: 2.770183
# Minibatch accuracy: 10.9%
# Validation accuracy: 4.9%
# Minibatch loss at step 450: 2.644421
# Minibatch accuracy: 22.0%
# Validation accuracy: 9.2%
# Minibatch loss at step 500: 2.993770
# Minibatch accuracy: 18.4%
# Validation accuracy: 7.3%
# Minibatch loss at step 550: 1.671963
# Minibatch accuracy: 50.1%
# Validation accuracy: 24.5%
# Minibatch loss at step 600: 1.589333
# Minibatch accuracy: 50.9%
# Validation accuracy: 39.8%
# Minibatch loss at step 650: 0.838360
# Minibatch accuracy: 78.5%
# Validation accuracy: 45.1%
# Minibatch loss at step 700: 0.938070
# Minibatch accuracy: 73.4%
# Validation accuracy: 52.1%
# Minibatch loss at step 750: 0.976279
# Minibatch accuracy: 71.2%
# Validation accuracy: 53.7%
# Minibatch loss at step 800: 0.412573
# Minibatch accuracy: 85.2%
# Validation accuracy: 60.3%
# Minibatch loss at step 850: 0.609986
# Minibatch accuracy: 82.4%
# Validation accuracy: 69.5%
# Minibatch loss at step 900: 0.274554
# Minibatch accuracy: 93.5%
# Validation accuracy: 68.3%
# Minibatch loss at step 950: 0.329794
# Minibatch accuracy: 88.7%
# Validation accuracy: 74.4%
# Minibatch loss at step 1000: 0.362251
# Minibatch accuracy: 90.0%
# Validation accuracy: 74.3%
# Test accuracy: 71.3%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 4.539947
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.995460
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.991016
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.965966
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.884488
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.092419
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.829512
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.944613
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.897975
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.794472
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.122154
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.752635
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.947942
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 650: 2.857726
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 700: 2.757043
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 750: 3.131599
# Minibatch accuracy: 2.8%
# Validation accuracy: 4.8%
# Minibatch loss at step 800: 2.709796
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 850: 2.964885
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 900: 2.827580
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 950: 2.744836
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 1000: 3.127092
# Minibatch accuracy: 4.4%
# Validation accuracy: 4.8%
# Test accuracy: 4.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 8.186500
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.729400
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.930141
# Minibatch accuracy: 8.4%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.784099
# Minibatch accuracy: 10.3%
# Validation accuracy: 4.9%
# Minibatch loss at step 200: 2.649018
# Minibatch accuracy: 24.7%
# Validation accuracy: 15.2%
# Minibatch loss at step 250: 2.612657
# Minibatch accuracy: 30.8%
# Validation accuracy: 28.8%
# Minibatch loss at step 300: 1.076397
# Minibatch accuracy: 68.7%
# Validation accuracy: 38.9%
# Minibatch loss at step 350: 1.183368
# Minibatch accuracy: 60.3%
# Validation accuracy: 49.9%
# Minibatch loss at step 400: 0.616051
# Minibatch accuracy: 83.8%
# Validation accuracy: 55.3%
# Minibatch loss at step 450: 0.520330
# Minibatch accuracy: 82.7%
# Validation accuracy: 67.9%
# Minibatch loss at step 500: 0.527799
# Minibatch accuracy: 86.1%
# Validation accuracy: 73.8%
# Minibatch loss at step 550: 0.260114
# Minibatch accuracy: 91.3%
# Validation accuracy: 74.3%
# Minibatch loss at step 600: 0.186139
# Minibatch accuracy: 96.4%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.100003
# Minibatch accuracy: 98.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.074084
# Minibatch accuracy: 98.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 750: 0.128027
# Minibatch accuracy: 97.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 800: 0.027705
# Minibatch accuracy: 99.7%
# Validation accuracy: 87.6%
# Minibatch loss at step 850: 0.036210
# Minibatch accuracy: 99.7%
# Validation accuracy: 88.7%
# Minibatch loss at step 900: 0.021601
# Minibatch accuracy: 99.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 950: 0.025293
# Minibatch accuracy: 99.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 1000: 0.035560
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.1%
# Test accuracy: 87.3%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 10.392336
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.705253
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.955030
# Minibatch accuracy: 12.7%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.744574
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.6%
# Minibatch loss at step 200: 2.789356
# Minibatch accuracy: 10.2%
# Validation accuracy: 5.1%
# Minibatch loss at step 250: 3.229090
# Minibatch accuracy: 0.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.592576
# Minibatch accuracy: 24.9%
# Validation accuracy: 10.9%
# Minibatch loss at step 350: 2.033644
# Minibatch accuracy: 36.1%
# Validation accuracy: 25.7%
# Minibatch loss at step 400: 1.203540
# Minibatch accuracy: 61.5%
# Validation accuracy: 38.4%
# Minibatch loss at step 450: 0.999358
# Minibatch accuracy: 69.4%
# Validation accuracy: 54.2%
# Minibatch loss at step 500: 0.923038
# Minibatch accuracy: 78.5%
# Validation accuracy: 57.8%
# Minibatch loss at step 550: 0.350809
# Minibatch accuracy: 89.6%
# Validation accuracy: 65.6%
# Minibatch loss at step 600: 0.418904
# Minibatch accuracy: 87.8%
# Validation accuracy: 72.7%
# Minibatch loss at step 650: 0.204712
# Minibatch accuracy: 96.1%
# Validation accuracy: 75.4%
# Minibatch loss at step 700: 0.169800
# Minibatch accuracy: 95.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 750: 0.230831
# Minibatch accuracy: 93.1%
# Validation accuracy: 84.4%
# Minibatch loss at step 800: 0.059809
# Minibatch accuracy: 98.6%
# Validation accuracy: 85.0%
# Minibatch loss at step 850: 0.071688
# Minibatch accuracy: 98.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 900: 0.035886
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 950: 0.035848
# Minibatch accuracy: 99.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 1000: 0.060483
# Minibatch accuracy: 99.0%
# Validation accuracy: 89.0%
# Test accuracy: 86.1%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 8.380652
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 3.003124
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.998169
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.965671
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 200: 2.889784
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 250: 3.086656
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 300: 2.832551
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 350: 2.947565
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 400: 2.897203
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 450: 2.796961
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 500: 3.118448
# Minibatch accuracy: 1.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 550: 2.753963
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 600: 2.949476
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 650: 2.857141
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 700: 2.758451
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 750: 3.129118
# Minibatch accuracy: 2.8%
# Validation accuracy: 4.8%
# Minibatch loss at step 800: 2.710312
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 850: 2.965884
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 900: 2.827218
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 950: 2.745713
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 1000: 3.125652
# Minibatch accuracy: 4.4%
# Validation accuracy: 4.8%
# Test accuracy: 4.7%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 12.565377
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.705305
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 100: 2.946939
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 150: 2.756955
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.3%
# Minibatch loss at step 200: 2.749180
# Minibatch accuracy: 11.9%
# Validation accuracy: 5.0%
# Minibatch loss at step 250: 3.242792
# Minibatch accuracy: 5.4%
# Validation accuracy: 5.3%
# Minibatch loss at step 300: 2.616245
# Minibatch accuracy: 14.2%
# Validation accuracy: 7.5%
# Minibatch loss at step 350: 2.498028
# Minibatch accuracy: 24.4%
# Validation accuracy: 17.9%
# Minibatch loss at step 400: 1.367783
# Minibatch accuracy: 60.8%
# Validation accuracy: 37.5%
# Minibatch loss at step 450: 1.452105
# Minibatch accuracy: 60.5%
# Validation accuracy: 44.9%
# Minibatch loss at step 500: 1.080749
# Minibatch accuracy: 73.8%
# Validation accuracy: 59.5%
# Minibatch loss at step 550: 0.517322
# Minibatch accuracy: 84.9%
# Validation accuracy: 63.8%
# Minibatch loss at step 600: 0.431989
# Minibatch accuracy: 87.6%
# Validation accuracy: 71.7%
# Minibatch loss at step 650: 0.253406
# Minibatch accuracy: 94.1%
# Validation accuracy: 75.3%
# Minibatch loss at step 700: 0.194299
# Minibatch accuracy: 95.6%
# Validation accuracy: 78.0%
# Minibatch loss at step 750: 0.271501
# Minibatch accuracy: 91.6%
# Validation accuracy: 81.4%
# Minibatch loss at step 800: 0.066815
# Minibatch accuracy: 98.6%
# Validation accuracy: 82.9%
# Minibatch loss at step 850: 0.062428
# Minibatch accuracy: 99.3%
# Validation accuracy: 86.1%
# Minibatch loss at step 900: 0.053191
# Minibatch accuracy: 99.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 950: 0.041544
# Minibatch accuracy: 99.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 1000: 0.076597
# Minibatch accuracy: 98.7%
# Validation accuracy: 88.7%
# Test accuracy: 85.6%
# Training set (2152, 100, 100) (2152,)
# Validation set (861, 100, 100) (861,)
# Test set (1291, 100, 100) (1291,)
# Training set (2152, 100, 100, 1) (2152, 21)
# Validation set (861, 100, 100, 1) (861, 21)
# Test set (1291, 100, 100, 1) (1291, 21)
# (1291, 21)
# Initialized
# Minibatch loss at step 0: 10.089574
# Minibatch accuracy: 10.2%
# Validation accuracy: 4.8%
# Minibatch loss at step 50: 2.691026
# Minibatch accuracy: 17.2%
# Validation accuracy: 7.7%
# Minibatch loss at step 100: 2.525475
# Minibatch accuracy: 18.8%
# Validation accuracy: 14.6%
# Minibatch loss at step 150: 1.623892
# Minibatch accuracy: 59.5%
# Validation accuracy: 29.3%
# Minibatch loss at step 200: 1.372476
# Minibatch accuracy: 59.3%
# Validation accuracy: 42.7%
# Minibatch loss at step 250: 1.395803
# Minibatch accuracy: 65.0%
# Validation accuracy: 51.8%
# Minibatch loss at step 300: 0.561149
# Minibatch accuracy: 86.4%
# Validation accuracy: 56.8%
# Minibatch loss at step 350: 0.969634
# Minibatch accuracy: 71.7%
# Validation accuracy: 46.1%
# Minibatch loss at step 400: 0.438426
# Minibatch accuracy: 90.8%
# Validation accuracy: 64.3%
# Minibatch loss at step 450: 0.399635
# Minibatch accuracy: 89.4%
# Validation accuracy: 70.6%
# Minibatch loss at step 500: 0.577725
# Minibatch accuracy: 85.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 550: 0.202066
# Minibatch accuracy: 95.3%
# Validation accuracy: 74.9%
# Minibatch loss at step 600: 0.302297
# Minibatch accuracy: 92.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 650: 0.173744
# Minibatch accuracy: 97.4%
# Validation accuracy: 78.5%
# Minibatch loss at step 700: 0.154360
# Minibatch accuracy: 96.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 750: 0.248563
# Minibatch accuracy: 93.7%
# Validation accuracy: 82.9%
# Minibatch loss at step 800: 0.071183
# Minibatch accuracy: 98.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.105938
# Minibatch accuracy: 98.4%
# Validation accuracy: 84.8%
# Minibatch loss at step 900: 0.066634
# Minibatch accuracy: 99.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 950: 0.075118
# Minibatch accuracy: 99.3%
# Validation accuracy: 86.2%
# Minibatch loss at step 1000: 0.118962
# Minibatch accuracy: 97.1%
# Validation accuracy: 85.8%
# Test accuracy: 83.8%

# %%
import matplotlib.pyplot as plt
import itertools
    
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


# confusion matrix
cnf_matrix = cm
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(num=1, figsize=(12, 12), dpi=80)
plot_confusion_matrix(cnf_matrix, classes=list(range(2)),title='Confusion matrix, without normalization')
#plt.figure(num=1, figsize=(8, 6), dpi=80)

# Plot normalized confusion matrix
plt.figure(num=2, figsize=(12, 12), dpi=80)
plot_confusion_matrix(cnf_matrix, classes=list(range(2)), normalize=True, title='Normalized confusion matrix')
#plt.figure(num=2, figsize=(8, 6), dpi=80)

plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix
